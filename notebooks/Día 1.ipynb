# %%
nombre_lote = "Lote_7"
area_texto = "8.4"  # hectáreas, viene como texto
dosis_texto = "150"  # kg de fertilizante por hectárea
cultivo = "Maíz"
lote_certificado = "True"  # ¡ojo! esto sigue siendo texto, no un bool real

area_ha = float(area_texto)
dosis_kg_ha = int(dosis_texto)
certificado = lote_certificado == "True"

total_fertilizante = area_ha * dosis_kg_ha

print(f"Lote: {nombre_lote} ({cultivo})")
print(f"Área: {area_ha} ha")
print(f"Fertilizante necesario: {total_fertilizante} kg por ha")
print(f"¿Certificado?: {certificado} (tipo: {type(certificado)})")
# Out:
# Lote: Lote_7 (Maíz)
# Área: 8.4 ha
# Fertilizante necesario: 1260.0 kg por ha
# ¿Certificado?: True (tipo: <class 'bool'>)
