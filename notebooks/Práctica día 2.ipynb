# %%
finca = {
    "nombre": "Finca Santa Rosa",
    "lotes": [
        {"id":"L1","cultivo":"Café","area_ha":4.2,"pH_texto":"6.5"},
        {"id":"L2","cultivo":"Maíz","area_ha":6.1,"pH_texto":"5.8"},
        {"id":"L3","cultivo":"Café","area_ha":3.3,"pH_texto":"N/A"}
    ]
}
area_total = finca["lotes"][0]["area_ha"] + finca["lotes"][1]["area_ha"] + finca["lotes"][2]["area_ha"]
print("Finca: ",finca["nombre"])
print(f"El Lote {finca['lotes'][0]['id']} tiene {finca['lotes'][0]['cultivo']} en {finca['lotes'][0]['area_ha']} hectáreas")
print(f"El Lote {finca['lotes'][1]['id']} tiene {finca['lotes'][1]['cultivo']} en {finca['lotes'][1]['area_ha']} hectáreas")
print(f"El Lote {finca['lotes'][-1]['id']} tiene {finca['lotes'][-1]['cultivo']} en {finca['lotes'][-1]['area_ha']} hectáreas")
print("El área total es ",area_total)
# Out:
# Finca:  Finca Santa Rosa
# El Lote L1 tiene Café en 4.2 hectáreas
# El Lote L2 tiene Maíz en 6.1 hectáreas
# El Lote L3 tiene Café en 3.3 hectáreas
# El área total es  13.600000000000001
