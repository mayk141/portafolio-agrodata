# %%
import numpy as np
import pandas as pd

# Crea un array simple
arr = np.array([1, 2, 3])
print(f"NumPy array: {arr}")

# Crea un DataFrame
df = pd.DataFrame({'lote': ['A', 'B'], 'rendimiento': [45, 52]})
print(df)
# Out:
# NumPy array: [1 2 3]
#   lote  rendimiento
# 0    A           45
# 1    B           52
